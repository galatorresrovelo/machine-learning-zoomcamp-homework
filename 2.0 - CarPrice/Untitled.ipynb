# %%
MACHINE LEARNING FOR REGRESSION

# %%
import pandas as pd
import numpy as np

# %%
DATA PREPARATION

# %%
data = ''

# %%
# !wget $data
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.
